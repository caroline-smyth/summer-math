# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn
seaborn.set()

import wrds
WRDS_LOGIN = 'cssmyth'

# %%
#conn = wrds.Connection(wrds_username=WRDS_LOGIN)

# %%
df = pd.read_parquet("your_file.parquet")

# %%
wrds_names_query = conn.get_table(library='crsp', table='wrds_names_query').copy() # get v2 table, which has secinfostartdt and enddt

# %%
msf = conn.get_table(library='crsp', table='msf').copy() # msf table, which has firm weights

# %%
import pandas as pd
print(f"Pandas version: {pd.__version__}")
print(f"CoW enabled: {pd.options.mode.copy_on_write}")
print(f"msf type: {type(msf)}")
print(f"msf is view: {msf._is_view if hasattr(msf, '_is_view') else 'N/A'}")
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# Pandas version: 2.2.3
# CoW enabled: False
# msf type: <class 'pandas.core.frame.DataFrame'>
# msf is view: False

# %%
# compute weight for all CRSP securities per month
msf = msf.copy()

msf['mktcap'] = msf['prc'].abs() * msf['shrout']
msf['total_mktcap'] = msf.groupby('date')['mktcap'].transform('sum')
msf['weight'] = msf['mktcap'] / msf['total_mktcap']

msf['pctile'] = (
    msf.groupby('date')['weight'].rank(pct=True, ascending=False)
)

# %%
# make date a datetime type

msf['date'] = pd.to_datetime(msf['date'])

# start of security data and end of security data
wrds_names_query['securitybegdt'] = pd.to_datetime(wrds_names_query['securitybegdt'])
wrds_names_query['securityenddt'] = pd.to_datetime(wrds_names_query['securityenddt'])

# turn dates into month period for joins
msf['month']  = msf['date'].dt.to_period('M')
wrds_names_query['beg_month'] = wrds_names_query['securitybegdt'].dt.to_period('M')
wrds_names_query['end_month'] = wrds_names_query['securityenddt'].dt.to_period('M')

# anchor months for price/rank lookups
wrds_names_query['beg_anchor'] = wrds_names_query['beg_month'] - 1
wrds_names_query['end_anchor'] = wrds_names_query['end_month'] - 1

# %%
wrds_names_query['tradingsymbol'].unique()
# Out:
# <StringArray>
# ['OMFGA', 'OMFAC',    <NA>,  'GFGC',  'EWST', 'EWSTE', 'EWSTD',  'EGAS',
#   'MBNC',  'SABC',
#  ...
#   'BSFT',  'CBOE',  'CYDE',  'HSFT', 'PACTV',  'JGBO',  'VLTC',  'SANW',
#   'SCEI',  'TSLA']
# Length: 37765, dtype: string

# %%
# first and last month in msf universe
first_month = msf['month'].min()
last_month  = msf['month'].max()

#msf_cols = ['permno', 'month', 'pctile', 'weight', 'mktcap', 'total_mktcap']

#ent_keys = wrds_names_query.loc[wrds_names_query['beg_month'].notna(), ['permno','beg_month','beg_anchor']].copy()
#ent_keys = ent_keys[ent_keys['beg_anchor'] >= first_month]

drop_months = [
    pd.Period('1962-07', 'M'),
    pd.Period('1972-12', 'M'),
    pd.Period('2006-03', 'M'),
]

ent_keys = wrds_names_query.loc[
    wrds_names_query['beg_month'].notna(),
    ['permno','beg_month']
].copy()

ent_keys['next_month'] = ent_keys['beg_month'] + 1  # Period[M] arithmetic

# entrances 
df_ent = pd.merge(
    msf[['permno','month','pctile','weight','mktcap','total_mktcap']],
    ent_keys,
    left_on  = ['permno','month'],
    right_on = ['permno','next_month'],
    how      = 'inner'
)

df_ent['event'] = 'entrance'
df_ent = df_ent[df_ent['month'] != first_month]
df_ent = df_ent[~df_ent['month'].isin(drop_months)]
df_ent = df_ent.assign(event_month=df_ent['month'])

exit_keys = wrds_names_query.loc[
    wrds_names_query['end_month'].notna(),
    ['permno','end_month']
].copy()

exit_keys['prev_month'] = exit_keys['end_month'] - 1  # Period[M] arithmetic


# exits 
df_exit = pd.merge(
    msf[['permno','month','pctile','weight','mktcap','total_mktcap']],
    exit_keys, # wrds_names_query[['permno','end_month']] 
    left_on  = ['permno','month'],
    right_on = ['permno','prev_month'],
    how      = 'inner'
)

df_exit = df_exit[~df_exit['month'].isin(drop_months)]

df_exit['event'] = 'exit'
df_exit = df_exit[df_exit['month'] != last_month]
df_exit = df_exit[~df_exit['month'].isin(drop_months)]

df_exit = (df_exit
           .rename(columns={'end_month':'event_month'})
           .drop(columns=['prev_month'])
          )

# collapse to one entrance (earliest) and exit (latest) per permno
df_ent = (df_ent
          .sort_values('month')                    
          .drop_duplicates(subset='permno',     
                           keep='first')          
         )
df_exit = (df_exit
           .sort_values('month')                   
           .drop_duplicates(subset='permno',     
                            keep='last')          
          )

# combine
df_events = pd.concat([df_ent, df_exit], ignore_index=True)

# rename if downstream expects quantile but p sure it doesn't
df_events.rename(columns={'pctile':'quantile'}, inplace=True)

# %%
# counts of events by month and type
Y_increments = (
    df_events
    .groupby(['event_month', 'event'])
    .size()
    .unstack(fill_value=0)
    .rename(columns={'entrance': 'Y1_inc', 'exit': 'Y2_inc'})
    .sort_index()
)

# Y1 being num of entrances in that month, Y2 being num of exits in that month

Y_increments
# Out:
# event        Y1_inc  Y2_inc
# event_month
# 1926-01         509       0
# 1926-02          11       1
# 1926-03          10       3
# 1926-04           5       0
# 1926-05           6       3
# ...             ...     ...
# 2024-08         100      59
# 2024-09          62      67
# 2024-10         158      63
# 2024-11         112      68
# 2024-12          81    9812
#
# [1155 rows x 2 columns]

# %%
# total number of active securities per month

N_series = (
    msf
    .groupby('month')['permno']
    .nunique()
    .rename('N')
    .sort_index()
)

N_series.head()
# Out:
# month
# 1925-12    520
# 1926-01    530
# 1926-02    535
# 1926-03    540
# 1926-04    541
# Freq: M, Name: N, dtype: int64

# %%
# turn increments into cumulative counting processes
Y_cum = (
    Y_increments
    .cumsum()
    .rename(columns={'Y1_inc': 'Y1_cum', 'Y2_inc': 'Y2_cum'})
)

Y_cum
# Out:
# event        Y1_cum  Y2_cum
# event_month
# 1926-01         509       0
# 1926-02         520       1
# 1926-03         530       4
# 1926-04         535       4
# 1926-05         541       7
# ...             ...     ...
# 2024-08       38230   28779
# 2024-09       38292   28846
# 2024-10       38450   28909
# 2024-11       38562   28977
# 2024-12       38643   38789
#
# [1155 rows x 2 columns]

# %%
# combine everything into clean time series table

entrance_exit_panel = (
    N_series.to_frame()          # N
    .join(Y_increments, how='left')  # Y1_inc, Y2_inc
    .fillna(0)                   # months with no entrances or exits
    .assign(
        Y1_cum=lambda df: df['Y1_inc'].cumsum(),
        Y2_cum=lambda df: df['Y2_inc'].cumsum(),
    )
    .sort_index()
)

entrance_exit_panel.head()
# Out:
#            N  Y1_inc  Y2_inc  Y1_cum  Y2_cum
# month
# 1925-12  520     0.0     0.0     0.0     0.0
# 1926-01  530   509.0     0.0   509.0     0.0
# 1926-02  535    11.0     1.0   520.0     1.0
# 1926-03  540    10.0     3.0   530.0     4.0
# 1926-04  541     5.0     0.0   535.0     4.0

# %%
# make csv out of entrance/exit time series
entrance_exit_panel.to_csv('data/entrance_exit_panel.csv')

# %%
df_exit['permno']
# Out:
# 5281      10997
# 15014     13020
# 24899     15309
# 16846     13514
# 8505      11615
#           ...
# 61970     25183
# 61969     25182
# 61967     25181
# 147677    85731
# 186188    93436
# Name: permno, Length: 38789, dtype: Int64

# %%
# counts of each event type
counts = (df_events['event']
          .value_counts()
          .reindex(['entrance', 'exit'])
          .fillna(0)
          .astype(int))

n_entrances = counts.get('entrance', 0)
n_exits     = counts.get('exit', 0)

print(counts)
if n_exits:
    print(f"ratio (entrances : exits) = {n_entrances} : {n_exits} = {n_entrances/n_exits:.2f}")
else:
    print("No exits found; ratio undefined.")
# Out:
# event
# entrance    38643
# exit        38789
# Name: count, dtype: int64
# ratio (entrances : exits) = 38643 : 38789 = 1.00

# %%
import scipy.stats as stats
from pathlib import Path

# quantile histograms (ventile bins)
ventile_bins = np.linspace(0, 1, 21)
ent_q = df_events[df_events['event']=='entrance']['quantile']
exit_q = df_events[df_events['event']=='exit']['quantile']

"""
def prepare_beta_data(df_events):
    print('hello')
    # separate entrance and exit events
    entrance_data = df_events[df_events['event'] == 'entrance']['quantile'].dropna()
    exit_data = df_events[df_events['event'] == 'exit']['quantile'].dropna()
    
    print(f"Entrance events: {len(entrance_data)}")
    print(f"Exit events: {len(exit_data)}")
    
    return entrance_data, exit_data
# prep the data
ent_q, exit_q = prepare_beta_data(df_events)
"""

plt.hist(ent_q, bins=ventile_bins, alpha=0.6, label='Entrance', density=True)
plt.hist(exit_q, bins=ventile_bins, alpha=0.6, label='Exit', density=True)
plt.xlabel('Rank Ventile')
plt.ylabel('Density')
plt.legend()

out_dir = Path("images")
out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / "ventiles.pdf"

#plt.title('Entrance vs Exit Quantiles')
plt.savefig(out_path, bbox_inches="tight")
plt.show()

# %%
# extract the weight series for entrance and exit
weights_ent = df_events.loc[df_events['event']=='entrance', 'weight']
weights_exit = df_events.loc[df_events['event']=='exit', 'weight']

pos_ent = weights_ent[weights_ent > 0]
pos_exit = weights_exit[weights_exit > 0]

# get global min & max
w_min = min(pos_ent.min(), pos_exit.min())
w_max = max(pos_ent.max(), pos_exit.max())
# 20 logarithmically‐spaced bins between w_min and w_max
log_bins = np.geomspace(w_min, w_max, 21)

plt.figure(figsize=(10,6))
plt.hist(weights_ent, bins=log_bins, alpha=0.6, label='Entrance')
plt.hist(weights_exit, bins=log_bins, alpha=0.6, label='Exit')

# switch the x‐axis to log scale to match the bins
plt.xscale('log')
plt.xlabel('Market Weight (log scale)')
plt.ylabel('Density')
#plt.title('Entrance vs Exit Weights')
plt.legend()
out_path = out_dir / "log.pdf"

#plt.title('Entrance vs Exit Quantiles')
plt.savefig(out_path, bbox_inches="tight")
plt.show()

# %%
# sort data
x_ent = np.sort(weights_ent)
x_exit = np.sort(weights_exit)


# compute cumulative probabilities
y_ent  = np.arange(1, len(x_ent)+1) / len(x_ent)
y_exit = np.arange(1, len(x_exit)+1) / len(x_exit)

# plot as steps so looks like true cdf
"""
plt.figure(figsize=(8,5))
plt.step(x_ent,  y_ent,  where='post', label='Entrance CDF')
plt.step(x_exit, y_exit, where='post', label='Exit CDF')

plt.xscale('log')

plt.xlabel('Market Weight')
plt.ylabel('Cumulative Probability')
plt.title('Empirical CDF of Entrance vs. Exit Weights')
plt.legend()
plt.grid(True, which='both', linestyle='--', alpha=0.5)
plt.show()"""
# Out:
# "\nplt.figure(figsize=(8,5))\nplt.step(x_ent,  y_ent,  where='post', label='Entrance CDF')\nplt.step(x_exit, y_exit, where='post', label='Exit CDF')\n\nplt.xscale('log')\n\nplt.xlabel('Market Weight')\nplt.ylabel('Cumulative Probability')\nplt.title('Empirical CDF of Entrance vs. Exit Weights')\nplt.legend()\nplt.grid(True, which='both', linestyle='--', alpha=0.5)\nplt.show()"

# %%
print('Entrance mean pctile:', ent_q.mean())
print('Exit mean pctile:', exit_q.mean())

# share in bottom 20% vs top 20% 
for name, series in [('Entrance', ent_q), ('Exit', exit_q)]:
    print(name, 'bottom 20%:', (series <= 0.2).mean(),
          'top 20%:', (series >= 0.8).mean())
# Out:
# Entrance mean pctile: 0.6052236176822051
# Exit mean pctile: 0.6143113857822136
# Entrance bottom 20%: 0.07744922108657772 top 20%: 0.2814751241840264
# Exit bottom 20%: 0.13200103815208927 top 20%: 0.37420192058136514

# %%
# counts of each event type
counts = (df_events['event']
          .value_counts()
          .reindex(['entrance', 'exit'])
          .fillna(0)
          .astype(int))

n_entrances = counts.get('entrance', 0)
n_exits     = counts.get('exit', 0)

print(counts)
if n_exits:
    print(f"ratio (entrances : exits) = {n_entrances} : {n_exits} = {n_entrances/n_exits:.2f}")
else:
    print("No exits found; ratio undefined.")
# Out:
# event
# entrance    38643
# exit        38789
# Name: count, dtype: int64
# ratio (entrances : exits) = 38643 : 38789 = 1.00

# %%
# 1) How many events lose quantiles?
df_events.assign(q_missing=df_events['quantile'].isna()) \
         .groupby(['event','q_missing']).size()

# 2) Why are exit quantiles missing? (look at inputs to your pctile calc)
exit_missing = df_exit[df_exit['pctile'].isna()][['permno','month']]

probe = (msf.merge(exit_missing, on=['permno','month'], how='inner')
           [['permno','month','prc','shrout','mktcap','total_mktcap',
             'weight','pctile','ret']])

probe.isna().mean()  # fraction missing in each column
#probe['shrcd'].value_counts(dropna=False)
#probe['exchcd'].value_counts(dropna=False)
# Out:
# permno          0.000000
# month           0.000000
# prc             1.000000
# shrout          0.525097
# mktcap          1.000000
# total_mktcap    0.000000
# weight          1.000000
# pctile          1.000000
# ret             1.000000
# dtype: float64

# %%
from scipy.optimize import minimize
import warnings
warnings.filterwarnings('ignore')

# %%
# really unnecessary considering the dropna() in the next cell
def prepare_beta_data(df_events):
    # separate entrance and exit events
    entrance_data = df_events[df_events['event'] == 'entrance']['quantile']
    exit_data = df_events[df_events['event'] == 'exit']['quantile']
    
    print(f"Entrance events: {len(entrance_data)}")
    print(f"Exit events: {len(exit_data)}")
    
    return entrance_data, exit_data
# prep the data
entrance_data, exit_data = prepare_beta_data(df_events)
# Out:
# Entrance events: 38643
# Exit events: 38789

# %%
# fit beta distributions with data adjustment
def fit_beta_distribution(data, event_type):
    """
    Fit beta distribution to quantile data
    Returns parameters and goodness-of-fit statistics
    """
    # handle boundary values
    clean_data = data.dropna()
    #clean_data = data
    
    # Beta distribution requires values strictly between 0 and 1
    # apply small adjustment to boundary values
    epsilon = 1e-6
    clean_data = clean_data.copy()
    clean_data[clean_data <= 0] = epsilon
    clean_data[clean_data >= 1] = 1 - epsilon
    
    print(f"\n{event_type} Data Summary:")
    print(f"Original range: [{data.min():.6f}, {data.max():.6f}]")
    print(f"Adjusted range: [{clean_data.min():.6f}, {clean_data.max():.6f}]")
    print(f"Number of boundary adjustments: {((data <= 0) | (data >= 1)).sum()}")

    # fit beta distribution using method of moments and MLE
    alpha_hat, beta_hat, loc, scale = stats.beta.fit(clean_data, floc=0, fscale=1)
    
    # calc goodness of fit using adjusted data
    ks_stat, ks_pvalue = stats.kstest(clean_data, lambda x: stats.beta.cdf(x, alpha_hat, beta_hat))
    
    # calc aic, bic
    log_likelihood = np.sum(stats.beta.logpdf(clean_data, alpha_hat, beta_hat))
    n = len(clean_data)
    aic = 2 * 2 - 2 * log_likelihood  # 2 parameters (alpha, beta)
    bic = np.log(n) * 2 - 2 * log_likelihood
    
    results = {
        'alpha': alpha_hat,
        'beta': beta_hat,
        'ks_statistic': ks_stat,
        'ks_pvalue': ks_pvalue,
        'aic': aic,
        'bic': bic,
        'log_likelihood': log_likelihood,
        'n_observations': n,
        'adjusted_data': clean_data  # Store the adjusted data for later use
    }

    print(f"\n{event_type} Beta Distribution Parameters:")
    print(f"Alpha: {alpha_hat:.4f}")
    print(f"Beta: {beta_hat:.4f}")
    print(f"KS Test p-value: {ks_pvalue:.4f}")
    print(f"AIC: {aic:.2f}")
    print(f"BIC: {bic:.2f}")
    
    return results

# fit distributions
entrance_params = fit_beta_distribution(entrance_data, "ENTRANCE")
exit_params = fit_beta_distribution(exit_data, "EXIT")
# Out:
# ENTRANCE Data Summary:
# Original range: [0.001109, 1.000000]
# Adjusted range: [0.001109, 0.999999]
# Number of boundary adjustments: 16
#
# ENTRANCE Beta Distribution Parameters:
# Alpha: 1.4858
# Beta: 0.9442
# KS Test p-value: 0.0000
# AIC: -6494.01
# BIC: -6476.89
#
# EXIT Data Summary:
# Original range: [0.000103, 1.000000]
# Adjusted range: [0.000103, 0.999999]
# Number of boundary adjustments: 61
#
# EXIT Beta Distribution Parameters:
# Alpha: 0.9859
# Beta: 0.6026
# KS Test p-value: 0.0000
# AIC: -11413.48
# BIC: -11396.36

# %%
# checking amounts post na drop
used_entrances = df_ent['pctile'].notna().sum()
used_exits     = df_exit['pctile'].notna().sum()

print(used_entrances)
print(used_exits)
# Out:
# 38451
# 38530

# %%
# create basic distribution plots using adjusted data — one figure per plot
x = np.linspace(0, 1, 1000)
entrance_data_adj = entrance_params['adjusted_data']
exit_data_adj = exit_params['adjusted_data']

# entrance distribution
plt.figure(figsize=(6, 5))
plt.hist(entrance_data_adj, bins=20, alpha=0.7, density=True, label='Entrance Data')
plt.plot(x, stats.beta.pdf(x, entrance_params['alpha'], entrance_params['beta']),
         linewidth=2, label=f'Beta({entrance_params["alpha"]:.2f}, {entrance_params["beta"]:.2f})')
plt.title('Entrance Events: Market Rank Distribution')
plt.xlabel('Market Rank Quantile')
plt.ylabel('Density')
plt.legend()
plt.grid(True, alpha=0.3)
out_path_entrance = out_dir / "beta_entrance.pdf"
plt.tight_layout()
plt.savefig(out_path_entrance, bbox_inches="tight")
plt.show()
plt.close()

# exit distribution
plt.figure(figsize=(6, 5))
plt.hist(exit_data_adj, bins=20, alpha=0.7, density=True, label='Exit Data')
plt.plot(x, stats.beta.pdf(x, exit_params['alpha'], exit_params['beta']),
         linewidth=2, label=f'Beta({exit_params["alpha"]:.2f}, {exit_params["beta"]:.2f})')
plt.title('Exit Events: Market Rank Distribution')
plt.xlabel('Market Rank Quantile')
plt.ylabel('Density')
plt.legend()
plt.grid(True, alpha=0.3)
out_path_exit = out_dir / "beta_exit.pdf"
plt.tight_layout()
plt.savefig(out_path_exit, bbox_inches="tight")
plt.show()
plt.close()

# comparison plot
plt.figure(figsize=(6, 5))
plt.plot(x, stats.beta.pdf(x, entrance_params['alpha'], entrance_params['beta']),
         linewidth=2, label='Entrance Beta Distribution')
plt.plot(x, stats.beta.pdf(x, exit_params['alpha'], exit_params['beta']),
         linewidth=2, label='Exit Beta Distribution')
plt.title('Comparison: Entrance vs Exit Distributions')
plt.xlabel('Market Rank Quantile')
plt.ylabel('Density')
plt.legend()
plt.grid(True, alpha=0.3)
out_path_comp = out_dir / "beta_comparison.pdf"
plt.tight_layout()
plt.savefig(out_path_comp, bbox_inches="tight")
plt.show()
plt.close()

# %%
#Q-Q plots for goodness of fit using adjusted data
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Use adjusted data
entrance_data_adj = entrance_params['adjusted_data']
exit_data_adj = exit_params['adjusted_data']

# Q-Q plot for entrance
stats.probplot(entrance_data_adj, dist=stats.beta, sparams=(entrance_params['alpha'], entrance_params['beta']), plot=axes[0])
axes[0].set_title('Q-Q Plot: Entrance Data vs Beta Distribution')
axes[0].grid(True, alpha=0.3)

# Q-Q plot for exit
stats.probplot(exit_data_adj, dist=stats.beta, sparams=(exit_params['alpha'], exit_params['beta']), plot=axes[1])
axes[1].set_title('Q-Q Plot: Exit Data vs Beta Distribution')
axes[1].grid(True, alpha=0.3)

plt.savefig('images/qq.png')
plt.tight_layout()
plt.show()

# %%
# calculate probabilities by market rank deciles
def calculate_entry_exit_probabilities(entrance_params, exit_params, quantile_range=None):
    """
    Calculate probabilities of entry/exit for different market rank ranges
    """
    if quantile_range is None:
        quantile_range = np.linspace(0, 1, 11)  # Deciles
    
    results = []
    
    for i in range(len(quantile_range)-1):
        lower = quantile_range[i]
        upper = quantile_range[i+1]
        
        # calculate probabilities using CDF
        entrance_prob = (stats.beta.cdf(upper, entrance_params['alpha'], entrance_params['beta']) - 
                        stats.beta.cdf(lower, entrance_params['alpha'], entrance_params['beta']))
        
        exit_prob = (stats.beta.cdf(upper, exit_params['alpha'], exit_params['beta']) - 
                    stats.beta.cdf(lower, exit_params['alpha'], exit_params['beta']))
        
        results.append({
            'quantile_range': f"{lower:.1f}-{upper:.1f}",
            'entrance_probability': entrance_prob,
            'exit_probability': exit_prob,
            'ratio_exit_to_entrance': exit_prob / entrance_prob if entrance_prob > 0 else np.inf
        })
    
    return pd.DataFrame(results)

# calculate probabilities
prob_df = calculate_entry_exit_probabilities(entrance_params, exit_params)
print("PROBABILITY ANALYSIS BY MARKET RANK DECILE:")
print(prob_df.round(4))
# Out:
# PROBABILITY ANALYSIS BY MARKET RANK DECILE:
#   quantile_range  entrance_probability  exit_probability  \
# 0        0.0-0.1                0.0305            0.0638
# 1        0.1-0.2                0.0552            0.0654
# 2        0.2-0.3                0.0715            0.0682
# 3        0.3-0.4                0.0849            0.0719
# 4        0.4-0.5                0.0969            0.0766
# 5        0.5-0.6                0.1080            0.0827
# 6        0.6-0.7                0.1188            0.0913
# 7        0.7-0.8                0.1298            0.1043
# 8        0.8-0.9                0.1421            0.1284
# 9        0.9-1.0                0.1624            0.2473
#
#    ratio_exit_to_entrance
# 0                  2.0936
# 1                  1.1848
# 2                  0.9549
# 3                  0.8469
# 4                  0.7906
# 5                  0.7660
# 6                  0.7682
# 7                  0.8035
# 8                  0.9041
# 9                  1.5231

# %%
# visualize probability analysis
fig, ax = plt.subplots(figsize=(12, 6))

# Probability comparison by decile
deciles = range(len(prob_df))
width = 0.35

ax.bar([x - width/2 for x in deciles], prob_df['entrance_probability'], 
           width, label='Entrance Probability', alpha=0.7, color='blue')
ax.bar([x + width/2 for x in deciles], prob_df['exit_probability'], 
           width, label='Exit Probability', alpha=0.7, color='red')
ax.set_xlabel('Market Rank Decile')
ax.set_ylabel('Probability')
ax.set_title('Entry vs Exit Probabilities by Market Rank Decile')
ax.set_xticks(deciles)
ax.set_xticklabels(prob_df['quantile_range'], rotation=45)
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
x = df_events.loc[df_events['event']=='entrance', 'quantile'].to_numpy()
y = df_events.loc[df_events['event']=='exit',     'quantile'].to_numpy()

import numpy as np
x = x[np.isfinite(x)]
y = y[np.isfinite(y)]

from scipy.stats import ks_2samp, mannwhitneyu, anderson_ksamp

ks  = ks_2samp(x, y, alternative='two-sided')              # beware: KS assumes continuous; ties make p conservative
mw  = mannwhitneyu(x, y, alternative='two-sided', method='asymptotic')  # or method='exact' if both samples small
ad  = anderson_ksamp([x, y])

print(f"Kolmogorv-Smirnov: {ks}")
print(f"Mann Whitney: {mw}")
print(f"Anderson-Darling: {ad}")
# Out:
# Kolmogorv-Smirnov: KstestResult(statistic=np.float64(0.11030627774828883), pvalue=np.float64(2.1200366400463556e-204), statistic_location=np.float64(0.8841442072103605), statistic_sign=np.int8(1))
# Mann Whitney: MannwhitneyuResult(statistic=np.float64(707304499.0), pvalue=np.float64(1.9611561111957886e-27))
# Anderson-Darling: Anderson_ksampResult(statistic=np.float64(675.600630167688), critical_values=array([0.325, 1.226, 1.961, 2.718, 3.752, 4.592, 6.546]), pvalue=np.float64(0.001))

# %%
m, n = len(x), len(y)
U    = mw.statistic
rank_biserial = 1 - (2*U)/(m*n)  # >0 means entrances tend to have larger values than exits

median_diff = np.median(x) - np.median(y)

# %%
from scipy.stats import epps_singleton_2samp
es = epps_singleton_2samp(x, y)

# %%
# statistical tests to compare distributions
def compare_distributions(entrance_data, exit_data):
    x = df_events.loc[df_events['event']=='entrance', 'quantile'].to_numpy()
    y = df_events.loc[df_events['event']=='exit',     'quantile'].to_numpy()
    
    x = x[np.isfinite(x)]
    y = y[np.isfinite(y)]
    # Kolmogorov-Smirnov test
    ks_stat, ks_pvalue = stats.ks_2samp(x, y)
    
    # Mann-Whitney U test
    mw_stat, mw_pvalue = stats.mannwhitneyu(x, y, alternative='two-sided')
    
    # Anderson-Darling test
    try:
        ad_stat, ad_critical, ad_significance = stats.anderson_ksamp([x, y])
    except:
        ad_stat, ad_significance = np.nan, np.nan
    
    print("STATISTICAL COMPARISON OF ENTRANCE vs EXIT DISTRIBUTIONS:")
    print(f"Kolmogorov-Smirnov Test: max vertical distance={ks_stat:.4f}, p-value={ks_pvalue:.4f}")
    print(f"Mann-Whitney U Test: statistic={mw_stat:.0f}, p-value={mw_pvalue:.4f}")
    if not np.isnan(ad_stat):
        print(f"Anderson-Darling Test: statistic={ad_stat:.4f}, significance={ad_significance:.4f}")
    
    return {
        'ks_statistic': ks_stat,
        'ks_pvalue': ks_pvalue,
        'mw_statistic': mw_stat,
        'mw_pvalue': mw_pvalue,
        'ad_statistic': ad_stat,
        'ad_significance': ad_significance
    }

# Run statistical comparison
comparison_stats = compare_distributions(entrance_data, exit_data)
# Out:
# STATISTICAL COMPARISON OF ENTRANCE vs EXIT DISTRIBUTIONS:
# Kolmogorov-Smirnov Test: max vertical distance=0.1103, p-value=0.0000
# Mann-Whitney U Test: statistic=707304499, p-value=0.0000
# Anderson-Darling Test: statistic=675.6006, significance=0.0010

# %%
# summary statistics and interpretation
print("\nSUMMARY STATISTICS:")
print("="*50)

print(f"\nENTRANCE DISTRIBUTION:")
print(f"Alpha: {entrance_params['alpha']:.4f}")
print(f"Beta: {entrance_params['beta']:.4f}")
print(f"Mean: {entrance_params['alpha']/(entrance_params['alpha']+entrance_params['beta']):.4f}")
print(f"Variance: {(entrance_params['alpha']*entrance_params['beta'])/((entrance_params['alpha']+entrance_params['beta'])**2*(entrance_params['alpha']+entrance_params['beta']+1)):.4f}")

if entrance_params['alpha'] > 1 and entrance_params['beta'] > 1:
    mode_entrance = (entrance_params['alpha']-1)/(entrance_params['alpha']+entrance_params['beta']-2)
    print(f"Mode: {mode_entrance:.4f}")

print(f"\nEXIT DISTRIBUTION:")
print(f"Alpha: {exit_params['alpha']:.4f}")
print(f"Beta: {exit_params['beta']:.4f}")
print(f"Mean: {exit_params['alpha']/(exit_params['alpha']+exit_params['beta']):.4f}")
print(f"Variance: {(exit_params['alpha']*exit_params['beta'])/((exit_params['alpha']+exit_params['beta'])**2*(exit_params['alpha']+exit_params['beta']+1)):.4f}")

if exit_params['alpha'] > 1 and exit_params['beta'] > 1:
    mode_exit = (exit_params['alpha']-1)/(exit_params['alpha']+exit_params['beta']-2)
    print(f"Mode: {mode_exit:.4f}")

print(f"\nINTERPRETATION:")
print("="*50)
if entrance_params['alpha'] > entrance_params['beta']:
    print("• Entrance: Firms tend to enter at HIGHER market ranks (top of market)")
else:
    print("• Entrance: Firms tend to enter at LOWER market ranks (bottom of market)")
    
if exit_params['alpha'] > exit_params['beta']:
    print("• Exit: Firms tend to exit at HIGHER market ranks (top of market)")
else:
    print("• Exit: Firms tend to exit at LOWER market ranks (bottom of market)")

print(f"\n• Statistical significance (KS test): {'SIGNIFICANT' if comparison_stats['ks_pvalue'] < 0.05 else 'NOT SIGNIFICANT'} (p={comparison_stats['ks_pvalue']:.4f})")
# Out:
# SUMMARY STATISTICS:
# ==================================================
#
# ENTRANCE DISTRIBUTION:
# Alpha: 1.4858
# Beta: 0.9442
# Mean: 0.6114
# Variance: 0.0693
#
# EXIT DISTRIBUTION:
# Alpha: 0.9859
# Beta: 0.6026
# Mean: 0.6206
# Variance: 0.0910
#
# INTERPRETATION:
# ==================================================
# • Entrance: Firms tend to enter at HIGHER market ranks (top of market)
# • Exit: Firms tend to exit at HIGHER market ranks (top of market)
#
# • Statistical significance (KS test): SIGNIFICANT (p=0.0000)

# %%
from scipy.stats import beta

# %%
α_b, β_b = entrance_params['alpha'], entrance_params['beta']
α_d, β_d = exit_params['alpha'],     exit_params['beta']

# define rank-dependent pdfs
pdf_birth = lambda x: beta.pdf(x, α_b, β_b, loc=0, scale=1)
pdf_death = lambda x: beta.pdf(x, α_d, β_d, loc=0, scale=1)

"""
num_entrances = df_ent.shape[0] # total count of entrance rows, same for exit next line
num_exits = df_exit.shape[0] # mind, though, that this is counting all the nans
"""
# could also drop the nans, as we do the beta and probably makes more sense 
num_entrances = df_ent.dropna().shape[0] 
num_exits = df_exit.dropna().shape[0]

ratio = num_entrances / num_exits if num_exits > 0 else np.inf

death_occurrence = 1.0
birth_occurrence = ratio * death_occurrence

print(f"birth_occurrence = {birth_occurrence:.6f}, death_occurrence = {death_occurrence:.6f}")

# rank‐dependent intensities thru multiplying by the pdf of birth and death from beta dist
λ_birth = lambda x: birth_occurrence * pdf_birth(x)
λ_death = lambda x: death_occurrence * pdf_death(x)
λ_total = lambda x: λ_birth(x) + λ_death(x)

# start with the empirical percentiles at the first month
raw = msf.loc[msf['month'] == first_month, 'pctile']
clean = raw.dropna().values
# clamp them so none are exactly 0 or 1
# thought this was already done but having an issue getting nan so...
N0 = 20000
base = clean
particles = np.random.choice(base, size=N0, replace=True)
#particles = np.clip(clean, 1e-6, 1-1e-6)

print("Seeded particle count:", particles.size)

def safe_pdf(x, α, β, eps=1e-6):
    x = np.clip(x, eps, 1-eps)
    return beta.pdf(x, α, β, loc=0, scale=1)

pdf_birth  = lambda x: safe_pdf(x, α_b, β_b)
pdf_death  = lambda x: safe_pdf(x, α_d, β_d)
λ_birth    = lambda x: birth_occurrence * pdf_birth(x)
λ_death    = lambda x: death_occurrence * pdf_death(x)
λ_total    = lambda x: λ_birth(x) + λ_death(x)
# confirmed thru testing atp that they're not nan! 

# assuming `particles` is (clamped) array of starting percentiles
birth_rates = λ_birth(particles)
death_rates = λ_death(particles)

nan_idx = np.where(np.isnan(birth_rates))[0]
total_rates = λ_total(particles)
# Out:
# birth_occurrence = 0.997950, death_occurrence = 1.000000
# Seeded particle count: 20000

# %%
# simulation horizon, in month units bc lambdas are per month
t = 0.0
i = 0
events = []  # to record (type, time, x)

# main loop - one Exp clock per particle
#while t < T_sim and len(particles) > 0:
while i < 10000:  
    # compute each particle’s total intensity
    i +=1 # counting loop iterations to make sure it doesn't just stop at 1
    rates = λ_total(particles)         # vector of λ_i
    # pull waiting times ~ Exp(λ_i)
    taus = np.random.exponential(1.0 / rates)
    
    # find next event
    i_star = np.argmin(taus)
    dt = taus[i_star]
    t += dt
    x_i = particles[i_star]
    
    # pick birth vs death
    if np.random.rand() < λ_birth(x_i) / λ_total(x_i):
        # birth: add a new particle at the same percentile
        particles = np.append(particles, x_i)
        particles = np.clip(particles, 1e-6, 1-1e-6)
        events.append(('birth', t, x_i))
    else:
        # death: remove that particle
        events.append(('death', t, x_i))
        particles = np.delete(particles, i_star)
#print("Loop iterations:", i)
#print("Events recorded:", len(events))

# %%
df_sim = pd.DataFrame(events, columns=['event', 'time', 'percentile'])
counts = df_sim['event'].value_counts()
print("Total events:", len(df_sim))
print("Birth events:", counts.get('birth', 0))
print("Death events:", counts.get('death', 0))

plt.figure()
plt.hist(df_sim[df_sim['event']=='birth']['percentile'], bins=20, density=True)
plt.title('Birth Event Percentiles')
plt.xlabel('Percentile')
plt.ylabel('Density')
plt.savefig('images/birth_p.pdf')
#plt.show()

plt.figure()
plt.hist(df_sim[df_sim['event']=='death']['percentile'], bins=20, density=True)
plt.title('Death Event Percentiles')
plt.xlabel('Percentile')
plt.ylabel('Density')
out_path = out_dir / "death_p.pdf"
plt.savefig(out_path, bbox_inches="tight")
#plt.show()

particle_counts = [raw.size]
times = [0.0]
count = raw.size
for etype, time_, _ in events:
    count += 1 if etype == 'birth' else -1
    times.append(time_)
    particle_counts.append(count)

plt.figure()
plt.plot(times, particle_counts)
plt.title('Particle Count Over Time')
plt.xlabel('Time (months)')
plt.ylabel('Particle Count')
out_path1 = out_dir / "particle_count.pdf"
plt.savefig(out_path1, bbox_inches="tight")
#plt.show()

x_vals = np.linspace(0, 1, 300)
plt.figure()
plt.hist(df_sim[df_sim['event']=='birth']['percentile'], bins=20, density=True, alpha=0.3)
plt.plot(x_vals, pdf_birth(x_vals))
plt.title('Simulated Birth Percentiles vs Beta PDF')
plt.xlabel('Percentile')
plt.ylabel('Density')
out_path1 = out_dir / "birth_density_beta.pdf"
plt.savefig(out_path1, bbox_inches="tight")
#plt.show()

"""
plt.figure()
plt.hist(df_sim[df_sim['event']=='death']['percentile'], bins=20, alpha=0.3)
plt.plot(x_vals, pdf_death(x_vals))
plt.title('Simulated Death Percentiles vs Beta PDF')
plt.xlabel('Percentile')
plt.ylabel('Density')
out_path1 = out_dir / "death_density_beta.pdf"
plt.savefig(out_path1, bbox_inches="tight")
plt.show()
"""

death = df_sim.loc[df_sim['event']=='death','percentile'].dropna()
pad = 0.01
lo = max(0.0, death.min() - pad)
hi = min(1.0, death.max() + pad)

F = lambda x: beta.cdf(x, α_d, β_d, loc=0, scale=1)
f = lambda x: beta.pdf(x, α_d, β_d, loc=0, scale=1)
Z = max(F(hi) - F(lo), 1e-12)# renormalizer, guard zero
f_cond = lambda x: f(x) / Z

bins = np.histogram_bin_edges(death, bins=20, range=(lo, hi))
x = np.linspace(lo, hi, 800)

plt.figure()
plt.hist(death, bins=bins, density=True, alpha=0.3)
plt.plot(x, f_cond(x))
plt.xlim(lo, hi)
plt.title('Simulated Death Percentiles vs Beta PDF')
plt.xlabel('Percentile'); plt.ylabel('Density')
out_path1 = out_dir / "death_density_beta.pdf"
plt.savefig(out_path1, bbox_inches="tight")
# Out:
# Total events: 10000
# Birth events: 5084
# Death events: 4916

# %%
death = df_sim.loc[df_sim['event']=='death','percentile'].dropna()
pad = 0.01
lo = max(0.0, death.min() - pad)
hi = min(1.0, death.max() + pad)

F = lambda x: beta.cdf(x, α_d, β_d, loc=0, scale=1)
f = lambda x: beta.pdf(x, α_d, β_d, loc=0, scale=1)
Z = max(F(hi) - F(lo), 1e-12)       # renormalizer, guard zero
f_cond = lambda x: f(x) / Z

bins = np.histogram_bin_edges(death, bins=20, range=(lo, hi))
x = np.linspace(lo, hi, 800)

plt.figure()
plt.hist(death, bins=bins, density=True, alpha=0.35, edgecolor='none', label='Data (density)')
plt.plot(x, f_cond(x), lw=2, label='Beta PDF (cond. on [lo,hi])')
plt.xlim(lo, hi)
plt.legend()
plt.title('Death Percentiles: histogram vs conditional Beta PDF')
plt.xlabel('Percentile'); plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
# expected density per bin under (conditional) PDF
bin_heights = []
for a, b in zip(bins[:-1], bins[1:]):
    p = (F(b) - F(a)) / Z                # prob mass in bin under f_cond
    bin_heights.append(p / (b - a))      # density height for that bin

# draw as a step to match the histogram
bin_edges = bins
plt.step(bin_edges[:-1], bin_heights, where='post', lw=2, label='Beta (bin-avg)')
plt.legend()

# %%
from scipy import stats

# --- split simulated samples ---
sim_birth = df_sim.loc[df_sim['event']=='birth', 'percentile'].to_numpy()
sim_death = df_sim.loc[df_sim['event']=='death', 'percentile'].to_numpy()

def one_sample_gof_beta(sample, alpha, beta, label, m_bins=10, seed=0):
    """One-sample GOF vs Beta(alpha, beta):
       KS, Cramér–von Mises, binned chi-square (equal-probability bins), Wasserstein-1."""
    sample = np.asarray(sample)
    sample = sample[(sample > 0) & (sample < 1)]
    out = {'n': sample.size}
    if sample.size < 10:
        out['note'] = f'[{label}] too few samples for reliable GOF'
        return out
    
    # KS and CvM against the theoretical Beta CDF
    ks   = stats.kstest(sample, 'beta', args=(alpha, beta))
    cvm  = stats.cramervonmises(sample, stats.beta.cdf, args=(alpha, beta))
    
    # Chi-square on equal-probability bins (using Beta quantiles)
    q = np.linspace(0, 1, m_bins + 1)
    bins = stats.beta.ppf(q, alpha, beta)
    bins[0], bins[-1] = 0.0, 1.0  # guard against -inf/inf edges
    hist, _ = np.histogram(sample, bins=bins)
    expected = np.full_like(hist, sample.size / m_bins, dtype=float)
    chi2 = stats.chisquare(hist, f_exp=expected)
    
    # Wasserstein distance vs a synthetic Beta sample (effect size, no p-value)
    rng = np.random.default_rng(seed)
    ref = stats.beta.rvs(alpha, beta, size=min(5000, max(1000, 2*sample.size)), random_state=rng)
    w1  = stats.wasserstein_distance(sample, ref)
    
    return {
        'n': sample.size,
        'ks_stat': ks.statistic,   'ks_p': ks.pvalue,
        'cvm_stat': cvm.statistic, 'cvm_p': cvm.pvalue,
        'chi2_stat': chi2.statistic, 'chi2_p': chi2.pvalue,
        'w1': w1
    }

print('One-sample GOF vs target Beta')
birth_gof = one_sample_gof_beta(sim_birth, α_b, β_b, 'birth')
death_gof = one_sample_gof_beta(sim_death, α_d, β_d, 'death')
print('Birth:', birth_gof)
print('Death:', death_gof)

# --- Calibration test for birth vs death choices ---
# For each recorded event with percentile x_j, predicted P(birth) = λ_birth(x_j) / λ_total(x_j).
xj = df_sim['percentile'].to_numpy()
pj = stats.beta.pdf(xj, α_b, β_b)
qj = stats.beta.pdf(xj, α_d, β_d)
p_hat = (birth_occurrence * pj) / (birth_occurrence * pj + death_occurrence * qj)  # predicted birth prob per event
y = (df_sim['event'].to_numpy() == 'birth').astype(float)  # 1 if birth, else 0

# Score test (approx N(0,1) under null):
S = np.sum(y - p_hat)
V = np.sum(p_hat * (1.0 - p_hat))
z = S / np.sqrt(V) if V > 0 else np.nan
pval_cal = 2 * stats.norm.sf(np.abs(z))
print('\nBernoulli calibration across events')
print(f'Z = {z:.3f}, p = {pval_cal:.4g}  (H0: events are birth with predicted prob p_hat(x))')

# --- Inter-arrival time sampler check ---
# Minimal edits inside your loop:
#   * before picking i_star, record `Lambda_sum = rates.sum()`
#   * after computing `dt`, append to lists: `lambdas.append(Lambda_sum)` and `dts.append(dt)`
# Then this block will work:

if 'dts' in globals() and 'lambdas' in globals() and len(dts) == len(lambdas) and len(dts) > 10:
    U = 1.0 - np.exp(-np.array(lambdas) * np.array(dts))  # should be Uniform(0,1)
    ks_u = stats.kstest(U, 'uniform')
    print('\n=== Event-time sampler check ===')
    print(f'Uniform-transform KS: stat={ks_u.statistic:.4f}, p={ks_u.pvalue:.4g}')
else:
    print('\n[Note] To test event times, record per-step `lambdas` and `dts` inside the loop as noted above.]')
# Out:
# One-sample GOF vs target Beta
# Birth: {'n': 5063, 'ks_stat': np.float64(0.030585666794240463), 'ks_p': np.float64(0.0001505065240358249), 'cvm_stat': np.float64(1.6026069181564775), 'cvm_p': np.float64(0.00010070645760906771), 'chi2_stat': np.float64(24.215089867667388), 'chi2_p': np.float64(0.003973902573336754), 'w1': np.float64(0.019100458067120605)}
# Death: {'n': 4937, 'ks_stat': np.float64(0.03351418543361051), 'ks_p': np.float64(2.9771576403060156e-05), 'cvm_stat': np.float64(1.760748948831693), 'cvm_p': np.float64(4.4117277190891535e-05), 'chi2_stat': np.float64(65.06805752481264), 'chi2_p': np.float64(1.3994069024346165e-10), 'w1': np.float64(0.016598077741478538)}
#
# Bernoulli calibration across events
# Z = 0.053, p = 0.9579  (H0: events are birth with predicted prob p_hat(x))
#
# [Note] To test event times, record per-step `lambdas` and `dts` inside the loop as noted above.]

# %%
# --- containers for new tests ---
pit_birth, pit_death = [], []              # hazard-weighted PIT values
lambdas, dts = [], []                      # for event-time transform

# dynamic expected vs observed in percentile bins
m_bins = 12
bins = np.linspace(0.0, 1.0, m_bins+1)
exp_birth_bins = np.zeros(m_bins)
obs_birth_bins = np.zeros(m_bins)
exp_death_bins = np.zeros(m_bins)
obs_death_bins = np.zeros(m_bins)

rng = np.random.default_rng(0)

# === your loop, with a few NEW lines ===
t = 0.0
i = 0
events = []
while i < 1000 and len(particles) > 0:
    i += 1
    # current per-particle rates
    rates_tot   = λ_total(particles)
    rates_birth = λ_birth(particles)
    rates_death = λ_death(particles)

    # event-time bookkeeping (for rescaling test)
    Lambda_sum = rates_tot.sum()

    # draw per-particle waiting times
    taus = np.random.exponential(1.0 / rates_tot)
    i_star = np.argmin(taus)
    dt = taus[i_star]
    t += dt
    x_i = particles[i_star]

    # record for event-time transform (done once per step)
    lambdas.append(Lambda_sum)
    dts.append(dt)

    # choose event type at the chosen location
    is_birth = rng.random() < (rates_birth[i_star] / rates_tot[i_star])

    # ---- Hazard-weighted PIT + dynamic-bin expectation (BIRTH) ----
    if is_birth:
        w = rates_birth
        denom = w.sum()
        # PIT with randomized tie handling (Dunn–Smyth)
        lt_mask = particles < x_i
        eq_mask = particles == x_i
        num = w[lt_mask].sum()
        ties = w[eq_mask].sum()
        u = rng.random()
        pit = (num + u * ties) / denom
        pit_birth.append(pit)

        # expected bin contributions this step (conditional on birth)
        step_weights = np.bincount(np.digitize(particles, bins) - 1,
                                   weights=w / denom, minlength=m_bins)
        exp_birth_bins += step_weights
        # observed bin
        b_idx = np.digitize(x_i, bins) - 1
        if 0 <= b_idx < m_bins:
            obs_birth_bins[b_idx] += 1

        # apply birth update (your current rule: clone at same x)
        particles = np.append(particles, x_i)
        particles = np.clip(particles, 1e-6, 1-1e-6)
        events.append(('birth', t, x_i))

    # ---- Hazard-weighted PIT + dynamic-bin expectation (DEATH) ----
    else:
        w = rates_death
        denom = w.sum()
        lt_mask = particles < x_i
        eq_mask = particles == x_i
        num = w[lt_mask].sum()
        ties = w[eq_mask].sum()
        u = rng.random()
        pit = (num + u * ties) / denom
        pit_death.append(pit)

        step_weights = np.bincount(np.digitize(particles, bins) - 1,
                                   weights=w / denom, minlength=m_bins)
        exp_death_bins += step_weights

        b_idx = np.digitize(x_i, bins) - 1
        if 0 <= b_idx < m_bins:
            obs_death_bins[b_idx] += 1

        # apply death update
        particles = np.delete(particles, i_star)
        events.append(('death', t, x_i))

# === TESTS ===

print('\n=== Hazard-weighted PIT (Uniform(0,1)) ===')
if len(pit_birth) >= 20:
    ks_birth = stats.kstest(pit_birth, 'uniform')
    print(f'Birth PIT  : KS stat={ks_birth.statistic:.4f}, p={ks_birth.pvalue:.4g}, n={len(pit_birth)}')
else:
    print('Birth PIT  : not enough events')

if len(pit_death) >= 20:
    ks_death = stats.kstest(pit_death, 'uniform')
    print(f'Death PIT  : KS stat={ks_death.statistic:.4f}, p={ks_death.pvalue:.4g}, n={len(pit_death)}')
else:
    print('Death PIT  : not enough events')

print('\n=== Dynamic binwise chi-square (counts vs expected) ===')
def chi2_test(obs, exp, label):
    mask = (exp > 1e-12)  # avoid zero-expected bins
    if mask.sum() >= 3:
        chi2 = stats.chisquare(obs[mask], f_exp=exp[mask])
        print(f'{label:>6}: chi2={chi2.statistic:.2f}, df={mask.sum()-1}, p={chi2.pvalue:.4g}')
    else:
        print(f'{label:>6}: insufficient expected mass')

chi2_test(obs_birth_bins, exp_birth_bins, 'Birth')
chi2_test(obs_death_bins, exp_death_bins, 'Death')

print('\n=== Event-time rescaling (Uniform(0,1)) ===')
if len(dts) >= 20:
    U = 1.0 - np.exp(-np.array(lambdas) * np.array(dts))
    ks_u = stats.kstest(U, 'uniform')
    print(f'Uniformized inter-arrivals: KS stat={ks_u.statistic:.4f}, p={ks_u.pvalue:.4g}, n={len(U)}')
else:
    print('Not enough events to test timing.')
# Out:
# === Hazard-weighted PIT (Uniform(0,1)) ===
# Birth PIT  : KS stat=0.0401, p=0.3836, n=504
# Death PIT  : KS stat=0.0483, p=0.1921, n=496
#
# === Dynamic binwise chi-square (counts vs expected) ===
#  Birth: chi2=9.21, df=11, p=0.6029
#  Death: chi2=9.43, df=11, p=0.5826
#
# === Event-time rescaling (Uniform(0,1)) ===
# Uniformized inter-arrivals: KS stat=0.0172, p=0.9242, n=1000
